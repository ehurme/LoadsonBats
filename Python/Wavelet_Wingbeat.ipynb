# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime # for parsing the Date and Time columns
import pandas as pd # for reading the data file

from wavelet import *
# %matplotlib inline

# %% [markdown]
# # Read data

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\ehumre\Dropbox\MPI\Phyllostomus\Fieldwork\Data\Tracking\DrySeason\AJcave\PH_ST_014_S2.csv', 
                 sep='\t', 
                 usecols=['TagID', 'Timestamp', 'X', 'Y', 'Z'])

# %%
#print(df)
#print(len(df))
print(np.shape(df))
plt.plot(df['Z'])
plt.show
# Out:
# (892176, 5)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
t = np.linspace(0,10,1000)
Y = np.array([np.sin(2*np.pi*2*t),np.sin(2*np.pi*2*t)]).T
print(Y[:,1])

plt.plot(Y[:,1])
plt.show()
# Out:
# [ 0.00000000e+00  1.25458030e-01  2.48933554e-01  3.68475395e-01
#   4.82194534e-01  5.88293965e-01  6.85097090e-01  7.71074213e-01
#   8.44866709e-01  9.05308500e-01  9.51444475e-01  9.82545587e-01
#   9.98120372e-01  9.97922715e-01  9.81955739e-01  9.50471757e-01
#   9.03968283e-01  8.43180172e-01  7.69068007e-01  6.82802917e-01
#   5.85748078e-01  4.79437162e-01  3.65550112e-01  2.45886586e-01
#   1.22337524e-01 -3.14473221e-03 -1.28577295e-01 -2.51978061e-01
#  -3.71397034e-01 -4.84947137e-01 -5.90834035e-01 -6.87384489e-01
#  -7.73072793e-01 -8.46544890e-01 -9.06639763e-01 -9.52407783e-01
#  -9.83125718e-01 -9.98308158e-01 -9.97715189e-01 -9.81356181e-01
#  -9.49489640e-01 -9.02619128e-01 -8.41485297e-01 -7.67054195e-01
#  -6.80501991e-01 -5.83196397e-01 -4.76675049e-01 -3.62621214e-01
#  -2.42837185e-01 -1.19215809e-01  6.28943332e-03  1.31695289e-01
#   2.55020076e-01  3.74315000e-01  4.87694944e-01  5.93368262e-01
# ...

# %%
Y = np.array([df['Z'],df['Z']]).T
analysis = FrequencyAnalysis(n_freqs=len(df), fsample=25, fmin=5, fmax=7)(Y[:1000])
plt.plot(analysis['frequency'][1])
plt.plot(analysis['frequency'][0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22564/2563135566.py in <module>
#       1 Y = np.array([df['Z'],df['Z']]).T
# ----> 2 analysis = FrequencyAnalysis(n_freqs=len(df), fsample=25, fmin=5, fmax=7)(Y[:1000])
#       3 plt.plot(analysis['frequency'][1])
#       4 plt.plot(analysis['frequency'][0])
#       5 plt.show()
#
# ~\Desktop\Github\LoadsonBats\Python\wavelet.py in __call__(self, X, n_jobs)
#     277         if X.shape[1] > 2:
#     278             raise ValueError('n_features must be 2')
# --> 279         freqs, amp, phase = wavelet_transform(X,
#     280                                               self.n_freqs,
#     281                                               self.fsample,
#
# ~\Desktop\Github\LoadsonBats\Python\wavelet.py in wavelet_transform(X, n_freqs, fsample, fmin, fmax, prob, omega0, log_scale, n_jobs)
# ...

# %%
# Out:
# [[ 0.00000000e+00  0.00000000e+00]
#  [ 1.25458030e-01  1.25458030e-01]
#  [ 2.48933554e-01  2.48933554e-01]
#  ...
#  [-2.48933554e-01 -2.48933554e-01]
#  [-1.25458030e-01 -1.25458030e-01]
#  [-4.89858720e-15 -4.89858720e-15]]

# %%
pa = PhaseAna()
phase = pa.getPhase(Y[:,0])
plt.plot(Y[:,0])
plt.plot(phase)
plt.show()
